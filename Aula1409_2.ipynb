# %% [markdown]
# <a href="https://colab.research.google.com/github/fernandadesousa12/meu-projeto-ml/blob/main/Aula1409_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Projeto: Classificação com Random Forest

## 1. Descrição
Objetivo: prever [target] a partir de [features].

## 2. Importações e Seed
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

SEED = 42
np.random.seed(SEED)

## 3. Dados
df = pd.read_csv('dados.csv')
df.head()

## 4. EDA (resumida)
df.describe()
df['target'].value_counts()

# %%
## 5. Pré-processamento
X = df.drop('target', axis=1)
y = df['target']
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=SEED
)

## 6. Modelagem
model = RandomForestClassifier(random_state=SEED)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
print(f"Acurácia: {accuracy_score(y_test, y_pred):.4f}")

## 7. Conclusão
- Resultados, limitações e próximos passos.
