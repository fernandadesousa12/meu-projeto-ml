# %% [markdown]
# <a href="https://colab.research.google.com/github/fernandadesousa12/meu-projeto-ml/blob/main/organizar_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Previsão de Clientes
#
# # Objetivo
#
# Este notebook tem como objetivo realizar uma análise dos dados e construir um modelo de Machine Learning para prever a variável target.
#
# Serão realizadas as seguintes etapas:
#
# - Importação das bibliotecas;
# - Configuração da semente aleatória;
# - Carregamento dos dados;
# - Preparação dos dados para o modelo;
# - Previsão;
# - Estatísticas e Gráficos
# - Avaliação dos resultados;
# - Conclusão.

# %%
# Importações das bibliotecas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Configuração da semente aleatória
SEED = 42
np.random.seed(SEED)

# %%
# Carregar dados
df = pd.read_csv('dados.csv')
df.head()

# %%
# Preparação dos dados

X = df.drop('target', axis=1)
y = df['target']

#  Preparação do modelo
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier()
model.fit(X, y)

# %%
# Previsão

y_pred = model.predict(X_test)
print(accuracy_score(y_test, y_pred))

# %%
# Estatísticas e Gráfico
df.describe()
plt.show()

# %%
print('Fim')
